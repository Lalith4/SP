# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd.read_csv(r'C:\Users\1507828\Desktop\New shift.csv')

# %%
df.head()
# Out:
#        DAYS     DATES  NISHITA  BHUSHAN  SWAPNIL  AVINASH  PUSHPA  LALITH  \
# 0    Friday  7-3-2020      NaN      NaN      NaN      NaN     NaN     NaN
# 1  Saturday  7-4-2020      NaN      NaN      NaN      NaN     NaN     NaN
# 2    Sunday  7-5-2020      NaN      NaN      NaN      NaN     NaN     NaN
# 3    Monday  7-6-2020      NaN      NaN      NaN      NaN     NaN     NaN
# 4   Tuesday  7-7-2020      NaN      NaN      NaN      NaN     NaN     NaN
#
#    ANCHIT  SANJEEV  HARISH  SAITEJA  MARIO  ALEXIS  PUNDALEEK  CHRISMA
# 0     NaN      NaN     NaN      NaN    NaN     NaN        NaN      NaN
# 1     NaN      NaN     NaN      NaN    NaN     NaN        NaN      NaN
# 2     NaN      NaN     NaN      NaN    NaN     NaN        NaN      NaN
# 3     NaN      NaN     NaN      NaN    NaN     NaN        NaN      NaN
# 4     NaN      NaN     NaN      NaN    NaN     NaN        NaN      NaN

# %%
dfno=df.iloc[:,2:]

# %%
dff=df[df['DAYS'] == 'Saturday']

# %%
df.columns
# Out:
# Index(['DAYS', 'DATES', 'NISHITA', 'BHUSHAN', 'SWAPNIL', 'AVINASH', 'PUSHPA',
#        'LALITH', 'ANCHIT', 'SANJEEV', 'HARISH', 'SAITEJA', 'MARIO', 'ALEXIS',
#        'PUNDALEEK', 'CHRISMA'],
#       dtype='object')

# %%
df[df['DAYS'] == 'Sunday'].T
# Out:
#                  2          9          16         23        30
# DAYS         Sunday     Sunday     Sunday     Sunday    Sunday
# DATES      7-5-2020  7-12-2020  7-19-2020  7-26-2020  8-2-2020
# NISHITA         NaN        NaN        NaN        NaN       NaN
# BHUSHAN         NaN        NaN        NaN        NaN       NaN
# SWAPNIL         NaN        NaN        NaN        NaN       NaN
# AVINASH         NaN        NaN        NaN        NaN       NaN
# PUSHPA          NaN        NaN        NaN        NaN       NaN
# LALITH          NaN        NaN        NaN        NaN       NaN
# ANCHIT          NaN        NaN        NaN        NaN       NaN
# SANJEEV         NaN        NaN        NaN        NaN       NaN
# HARISH          NaN        NaN        NaN        NaN       NaN
# SAITEJA         NaN        NaN        NaN        NaN       NaN
# MARIO           NaN        NaN        NaN        NaN       NaN
# ALEXIS          NaN        NaN        NaN        NaN       NaN
# ...

# %%
df= df.set_index(['DAYS','DATES'])

# %%
df.head()
# Out:
#                    NISHITA  BHUSHAN  SWAPNIL  AVINASH  PUSHPA  LALITH  ANCHIT  \
# DAYS     DATES
# Friday   7-3-2020      NaN      NaN      NaN      NaN     NaN     NaN     NaN
# Saturday 7-4-2020      NaN      NaN      NaN      NaN     NaN     NaN     NaN
# Sunday   7-5-2020      NaN      NaN      NaN      NaN     NaN     NaN     NaN
# Monday   7-6-2020      NaN      NaN      NaN      NaN     NaN     NaN     NaN
# Tuesday  7-7-2020      NaN      NaN      NaN      NaN     NaN     NaN     NaN
#
#                    SANJEEV  HARISH  SAITEJA  MARIO  ALEXIS  PUNDALEEK  CHRISMA
# DAYS     DATES
# Friday   7-3-2020      NaN     NaN      NaN    NaN     NaN        NaN      NaN
# Saturday 7-4-2020      NaN     NaN      NaN    NaN     NaN        NaN      NaN
# Sunday   7-5-2020      NaN     NaN      NaN    NaN     NaN        NaN      NaN
# Monday   7-6-2020      NaN     NaN      NaN    NaN     NaN        NaN      NaN
# ...

# %%
df.columns
# Out:
# Index(['NISHITA', 'BHUSHAN', 'SWAPNIL', 'AVINASH', 'PUSHPA', 'LALITH',
#        'ANCHIT', 'SANJEEV', 'HARISH', 'SAITEJA', 'MARIO', 'ALEXIS',
#        'PUNDALEEK', 'CHRISMA'],
#       dtype='object')

# %%
for i in df.columns:
    df[i] = df[i].apply(lambda v: np.random.choice([1,2]))

# %%
df
# Out:
#                      NISHITA  BHUSHAN  SWAPNIL  AVINASH  PUSHPA  LALITH  \
# DAYS      DATES
# Friday    7-3-2020         2        1        2        1       1       2
# Saturday  7-4-2020         1        2        2        2       2       1
# Sunday    7-5-2020         1        1        1        2       1       2
# Monday    7-6-2020         1        1        1        2       2       1
# Tuesday   7-7-2020         1        2        1        2       2       2
# Wednesday 7-8-2020         1        1        2        1       2       1
# Thursday  7-9-2020         1        2        2        1       2       2
# Friday    7-10-2020        2        2        1        1       2       2
# Saturday  7-11-2020        2        1        1        1       2       1
# Sunday    7-12-2020        1        1        1        1       1       1
# Monday    7-13-2020        1        1        1        2       2       2
# Tuesday   7-14-2020        2        2        1        2       2       1
# ...
